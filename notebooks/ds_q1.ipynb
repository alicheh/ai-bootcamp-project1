# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
data = pd.read_csv('../data/HBN.csv')
data.head()
# Out:
#    Unnamed: 0        id Enrol_Season  Age  Sex CGAS-Season  CGAS-Score  \
# 0           0  00008ff9         Fall    5    0      Winter        51.0
# 1           1  000fd460       Summer    9    0         NaN         NaN
# 2           2  00105258       Summer   10    1        Fall        71.0
# 3           3  00115b9f       Winter    9    0        Fall        71.0
# 4           4  0016bb22       Spring   18    1      Summer         NaN
#
#   Physical-Season  Physical-BMI  Physical-Height  ...  PCIAT-PCIAT_18  \
# 0            Fall     16.877316             46.0  ...             4.0
# 1            Fall     14.035590             48.0  ...             0.0
# 2            Fall     16.648696             56.5  ...             2.0
# 3          Summer     18.292347             56.0  ...             3.0
# 4             NaN           NaN              NaN  ...             NaN
#
#    PCIAT-PCIAT_19  PCIAT-PCIAT_20  PCIAT-PCIAT_Total  SDS-Season  \
# ...

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 20))

#Age
plt.subplot(3,2,1)
sns.histplot(data['Age'], kde=True, color='blue', bins=15)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')

#Weight
plt.subplot(3,2,2)
sns.histplot(data['Physical-Weight'], kde=True, color='green', bins=15)
plt.title('Weight Distribution')
plt.xlabel('Weight (lbs)')
plt.ylabel('Count')

# Height
plt.subplot(3,2,3)
sns.histplot(data['Physical-Height'], kde=True, color='orange', bins=15)
plt.title('Height Distribution')
plt.xlabel('Height (Inch)')
plt.ylabel('Count')

# Internet usage
plt.subplot(3,2,4)
sns.countplot(x='PreInt_EduHx-computerinternet_hoursday', data=data, color='purple')
plt.title('Internet Usage Distribution')
plt.xlabel('Internet Usage (hours/day)')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1, 2, 3], labels=['Less than 1h/day','Around 1h/day', 'Around 2hs/day', 'More than 3hs/day'])

#Gender disturbution
plt.subplot(3,2,5)
sns.countplot(x='Sex', data=data, color = 'red')
plt.title('Gender Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Men', 'Women'])


plt.tight_layout()
plt.show()
