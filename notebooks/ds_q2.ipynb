# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.cluster import DBSCAN

# %%
data = pd.read_csv('../data/HBN.csv')
data.head()
# Out:
#    Unnamed: 0        id Enrol_Season  Age  Sex CGAS-Season  CGAS-Score  \
# 0           0  00008ff9         Fall    5    0      Winter        51.0
# 1           1  000fd460       Summer    9    0         NaN         NaN
# 2           2  00105258       Summer   10    1        Fall        71.0
# 3           3  00115b9f       Winter    9    0        Fall        71.0
# 4           4  0016bb22       Spring   18    1      Summer         NaN
#
#   Physical-Season  Physical-BMI  Physical-Height  ...  PCIAT-PCIAT_18  \
# 0            Fall     16.877316             46.0  ...             4.0
# 1            Fall     14.035590             48.0  ...             0.0
# 2            Fall     16.648696             56.5  ...             2.0
# 3          Summer     18.292347             56.0  ...             3.0
# 4             NaN           NaN              NaN  ...             NaN
#
#    PCIAT-PCIAT_19  PCIAT-PCIAT_20  PCIAT-PCIAT_Total  SDS-Season  \
# ...

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
sns.boxplot(x='Sex', y='BIA-BIA_BMI', data=data)
plt.title('BMI/Sex')
plt.xlabel('Sex')
plt.ylabel('BMI')

plt.subplot(1, 3, 2)
sns.boxplot(x='Sex', y='BIA-BIA_BMR', data=data)
plt.title('BMR/Sex')
plt.xlabel('Sex')
plt.ylabel('BMR')

plt.subplot(1, 3, 3)
sns.boxplot(x='Sex', y='CGAS-Score', data=data)
plt.title('CGAS/Sex')
plt.xlabel('Sex')
plt.ylabel('CGAS-Score')

plt.tight_layout()
plt.show()

# %%
# dbscan = DBSCAN(eps=10, min_samples=2)
# data['Cluster'] = dbscan.fit_predict(data[['BIA-BIA_BMR', 'Sex']]) 

# outliers = data[data['Cluster'] == -1] 
# clustered_data = data[data['Cluster'] != -1]

# print(clustered_data)

# print(outliers)
data = data.drop([3205,3511])

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
sns.boxplot(x='Sex', y='BIA-BIA_BMI', data=data)
plt.title('BMI/Sex')
plt.xlabel('Sex')
plt.ylabel('BMI')

plt.subplot(1, 3, 2)
sns.boxplot(x='Sex', y='BIA-BIA_BMR', data=data)
plt.title('BMR/Sex')
plt.xlabel('Sex')
plt.ylabel('BMR')

plt.subplot(1, 3, 3)
sns.boxplot(x='Sex', y='CGAS-Score', data=data)
plt.title('CGAS/Sex')
plt.xlabel('Sex')
plt.ylabel('CGAS-Score')

plt.tight_layout()
plt.show()
